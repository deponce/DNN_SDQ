

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(YuvVGG420Bpp,YuvVGG420Acc,alpha=0.5,label="YUV")
plt.plot(SWX255VGG420Bpp,SWX255VGG420Acc,alpha=0.5,label="SWX255")
plt.plot(SWX422VGG420Bpp,SWX422VGG420Acc,alpha=0.5,label="SWX422")
plt.title("VGG [Resize --> Compression], 420")
plt.legend()

# %%
plt.plot(YuvVGG444Bpp,YuvVGG444Acc,alpha=0.5,label="YUV")
plt.plot(SWX255VGG444Bpp,SWX255VGG444Acc,alpha=0.5,label="SWX255")
plt.plot(SWX422VGG444Bpp,SWX422VGG444Acc,alpha=0.5,label="SWX422")
plt.title("VGG [Resize --> Compression], 444")
plt.legend()

# %%
MAX_Y = 19

# %%
YuvVGG444Acc = np.array([0.55458, 0.62712, 0.65076, 0.66282, 0.67182, 0.67606, 0.67764, 0.6804, 0.68148, 0.68356, 0.6845, 0.68564, 0.68788, 0.688, 0.68816, 0.6891, 0.6894, 0.68956, 0.68988])
YuvVGG444Bpp = np.array([0.3332, 0.45677, 0.5623, 0.66318, 0.77048, 0.863196, 0.94126, 1.031899, 1.09201, 1.19886, 1.2996, 1.42974, 1.58607, 1.73094, 2.0407867, 2.463374, 2.91340, 4.595755853,8.152159])

# %%
SWXVGG444Acc_2_422_sqrt3 = np.array([0.53058, 0.61512, 0.6435, 0.6566,0.66508, 0.67158,0.6738,0.6761,0.67854,0.68094,0.68228,0.68302,0.68476,0.68622,0.68724,0.68792,0.68846,0.6898,0.69026])
SWXVGG444Bpp_2_422_sqrt3 = np.array([0.334786, 0.459689, 0.5767113, 0.686434,0.79158,0.8945,0.9795,1.07207,1.16028,1.2555,1.36635,1.50455,1.668327,1.872776,2.177277,2.60845,3.27041,4.955179,9.72992])

# %%
SWXVGG444Acc_1_255_sqrt3 = [0.5342, 0.61606, 0.64402, 0.657, 0.66514, 0.67152, 0.67376, 0.6761, 0.67854, 0.68094, 0.68228, 0.68302, 0.68476, 0.68622, 0.68724, 0.68792, 0.68846, 0.6898, 0.69018]
SWXVGG444Bpp_1_255_sqrt3 = [0.35126, 0.47121, 0.58305, 0.68978, 0.79312, 0.894795, 0.97956, 1.07207, 1.16028, 1.2555, 1.36635, 1.50455, 1.668328, 1.87278, 2.17728, 2.60846, 3.27041, 4.95518, 12.72564]

# %%
# YuvVGG444Bpp_ = 24./YuvVGG444Bpp
# SWXVGG444Bpp_2_422_sqrt3_ = 24./SWXVGG444Bpp_2_422_sqrt3

# %%
print(len(SWXVGG444Acc_2_422_sqrt3))
plt.plot(YuvVGG444Bpp,YuvVGG444Acc,alpha=0.5,label="YUV")
plt.plot(SWXVGG444Bpp_2_422_sqrt3,SWXVGG444Acc_2_422_sqrt3,alpha=0.5,label="SWX422")
plt.plot(SWXVGG444Bpp_1_255_sqrt3,SWXVGG444Acc_1_255_sqrt3,alpha=0.5,label="SWX255")
plt.title("VGG [Compression --> Resize], 444")
plt.legend()
plt.savefig("SWXvsYUC.png", dpi=600)
# Out:
# 19
